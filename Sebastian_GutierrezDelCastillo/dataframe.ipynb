# %%
Analisis de csv  dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os

# %%
dato1= pd.read_csv("2023-10-04.csv")
dato2= pd.read_csv("2023-10-05.csv")
dato3= pd.read_csv("2023-10-06.csv")
dato4= pd.read_csv("2023-10-07.csv")
dato5= pd.read_csv("2023-10-08.csv")
dato6= pd.read_csv("2023-10-09.csv")

# %%
dato3.describe()
# Out:
#          Humedad   Temperatura     Presion
# count  49.000000     49.000000   49.000000
# mean   31.814286     41.221429  781.004490
# std     5.810642      4.069267  162.790884
# min    25.680000     28.120000    0.000000
# 25%    28.020000     39.090000  811.840000
# 50%    28.930000     40.390000  814.240000
# 75%    35.540000     45.720000  815.940000
# max    50.230000     47.360000  817.100000

# %%
fulldata= pd.concat([dato1,dato2,dato3,dato4,dato5,dato6])

# %%
fulldata.to_csv("fulldata.csv")

# %%
fulldata.hist()
# Out:
# array([[<Axes: title={'center': 'Humedad'}>,
#         <Axes: title={'center': ' Temperatura'}>],
#        [<Axes: title={'center': 'Presion'}>, <Axes: >]], dtype=object)

# %%
fig, ax1 = plt.subplots(figsize=(12,5))
ax1.set_xlabel("Tiempo")
ax1.set_ylabel("Temperatura")
ax1.plot(dato[" Temperatura"], label="Temperatura", color="r")
ax2=ax1.twinx()
ax2.set_ylabel("Humedad")
ax2.plot(dato["Humedad"],label="Humedad")
fig.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 ax1.set_xlabel("Tiempo")
#       3 ax1.set_ylabel("Temperatura")
# ----> 4 ax1.plot(dato[" Temperatura"], label="Temperatura", color="r")
#       5 ax2=ax1.twinx()
#       6 ax2.set_ylabel("Humedad")
#
# NameError: name 'dato' is not defined
